# %%
Minimax Algorithm

MiniMax algorithm is a search algorithm in AI, mostly use in 2 players competitive game such as:
    Chess
    Tic - Tac - Toe
    In this project: Pacman
    
The Goal is:
    Max player (or a team of Max players) trying to maximise the score
    Min player (or a team of Min players) trying to minimise the score

    At its core, minimax is a decision-making algorithm used in two-player, zero-sum games.
    It operates on the principle of minimizing the possible loss for a worst-case scenario—essentially "maximizing your minimum gain".

2. Core concept:
Asumming the opponent have chosen their optimal move.

Then:
The Max player will choose the move that will help them get the highest score.
The Min player will choose the move that will get the Lowest score.

3. Visualize tree
Example:
            MAX
          /     \
        MIN     MIN
       /  \     /  \
      3    5   2    9

Min player will choose the min of each leaf nodes:
    Min(3, 5) = 3
    Min(2, 9) = 2

Then the tree will look like:
            MAX
          /     \
         3       2

Max player will choose the max of each leaf nodes:
    Max(3, 2) = 3

Optimal path for Max is the left nodes in this case, that will earn them 3 points.

4. Formula of MiniMax:


10. Application
Deep Blue (1997)
